# %% [markdown]
# # Snapshot Workflow Merged
#
# This notebook was merged into `notebooks/augmentations.ipynb`.
# Use the merged notebook for full exploration and dataset generation.
# Reusable implementation now lives in `src/uno_vision/data/game_snapshots.py`.

# %%
import sys
from pathlib import Path

import numpy as np

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from uno_vision.data.game_snapshots import load_reference_card_pools, make_scene
from uno_vision.paths import GAME_SNAPSHOTS_DIR

card_images, card_masks = load_reference_card_pools()
scene, mask_canvas, placements = make_scene(
    card_images,
    card_masks,
    rng=np.random.default_rng(7),
)

print("Merged workflow is available in notebooks/augmentations.ipynb")
print(f"Card types loaded: {len(card_images)}")
print(f"Cards placed in demo scene: {len(placements)}")
print(f"Default save location: {GAME_SNAPSHOTS_DIR}")
# Out:
# Background generators ready.
